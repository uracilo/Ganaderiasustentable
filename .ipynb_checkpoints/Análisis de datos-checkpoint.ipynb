# %%
# Importación de las librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ambiental1 = 1

# %%
# Las variables del indice son: 
# Nivel de participacion en asociación con otros productores
NP = 1 
# Participacion en gestión
PG = 2
# Capacitación en productividad en el ultimo año
CP =3
# Satisfacción Personal
SP = 4
# Conduccion laboral 
CL = 5
#
SS =6
ET =7
# Espacio de produccion proporcional a los asociados

EP = 8
PS = 9

# %%
social1 = ((NP + PG + CP + SP)/(CL-(SS+ET))*EP)*(PS)
social1
# Out:
# -90.0

# %%
economico1 = 3

# %%
# Creación de un conjunto de datos aleatorio
angles = np.linspace(0, 2 * np.pi, 3, endpoint=False)
#values = [ambiental1,social1,economico1]
#values = [0.5,0.15,0.33]
values = [0.15,1,0.67]

# %%
# Se repite el primer valor para cerrar el gráfico
angles=np.concatenate((angles, [angles[0]]))
values=np.concatenate((values, [values[0]]))

# %%
labels=[' Social', ' Ambiental', ' Económico']

# %%
# Representación del mapa de calor
plt.polar(angles, values, 'o-', linewidth=2)
plt.fill(angles, values, alpha=0.25)
plt.thetagrids(angles * 180 / np.pi, labels)
plt.suptitle('Gestión Ganadera rancho 2', fontsize=16)
plt.savefig('Gestión Ganadera rancho 2.png')
